# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")

# %%
# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# %%
diamonds = sns.load_dataset("diamonds")

# %%
fmri = sns.load_dataset("fmri")

# %%
penguins = sns.load_dataset("penguins")

# %%
# Show the results of a linear regression within each dataset
sns.lmplot(
    data=df, x="x", y="y", col="dataset", hue="dataset",
    col_wrap=2, palette="rocket", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": 1}
)

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(11, 7))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="rocket",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)

# %%
f, ax = plt.subplots(figsize=(7, 7))
sns.lineplot(x="timepoint", y="signal",hue="event", style="event",data=fmri)

# %%
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=penguins, x="species", hue="species", shrink=.8, alpha=.8, legend=False, ax=axs[1])
f.tight_layout()

# %%
g = sns.relplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", col="sex")
g.set_axis_labels("Flipper length (mm)", "Bill length (mm)")

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", kind="kdeplot")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\alexp\Documents\eda_reference\eda_reference\SnsGallery.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alexp/Documents/eda_reference/eda_reference/SnsGallery.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", kind="kdeplot")
#
# File c:\Users\alexp\Documents\eda_reference\eda_reference\.venv\lib\site-packages\seaborn\axisgrid.py:2218, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2216 # Validate the plot kind
#    2217 plot_kinds = ["scatter", "hist", "hex", "kde", "reg", "resid"]
# -> 2218 _check_argument("kind", plot_kinds, kind)
# ...

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", kind="resid")
