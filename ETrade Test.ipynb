# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
summary_df = pd.read_csv('data/PortfolioDownload.csv', header=1, nrows=1)

# %%
summary_df.drop(summary_df.columns[[8, 9]], axis=1, inplace=True)

# %%
summary_df['2022 Ending Balance'] = summary_df['Net Account Value'] - summary_df['2023 Contributions']

# %%
summary_df
# Out:
#           Account  Net Account Value  Total Gain $  Total Gain %  \
# 0  Roth IRA -5590           15825.57       -575.05         -3.54
#
#    Day's Gain Unrealized $  Day's Gain Unrealized %  2023 Contributions  \
# 0                        0                        0             4441.44
#
#    Cash Purchasing Power  2022 Ending Balance
# 0                 137.88             11384.13

# %%
summary_df.plot(x='Account', y=['2022 Ending Balance', '2023 Contributions', 'Net Account Value'], kind='bar', figsize=(10, 5))
# Out:
# <AxesSubplot: xlabel='Account'>

# %%
df = pd.read_csv('data/PortfolioDownload.csv', header=10)

# %%
df = df.iloc[1:73,:]

# %%
# rename symbol column to date
df.rename(columns={'Symbol': 'Date'}, inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Date', inplace=True)

# %%
df.head(10)
# Out:
#             Last Price $  Change $  Change %  Quantity  Price Paid $  \
# Date
# 2021-08-02         42.49       0.0       0.0   122.599       48.9400
# 2021-12-30         42.49       0.0       0.0     2.385       48.1048
# 2021-12-30         42.49       0.0       0.0     0.844       48.0924
# 2021-12-30         42.49       0.0       0.0     3.708       48.1068
# 2022-02-22         42.49       0.0       0.0    12.274       44.4395
# 2022-03-10         42.49       0.0       0.0     6.301       43.1678
# 2022-03-24         42.49       0.0       0.0     6.037       45.3006
# 2022-04-05         42.49       0.0       0.0     6.019       45.3099
# 2022-04-29         42.49       0.0       0.0     6.503       41.9376
# 2022-05-04         42.49       0.0       0.0     6.328       43.0973
#
#             Day's Gain $  Total Gain $  Total Gain %    Value $
# Date
# 2021-08-02           0.0     -790.7636      -13.1794  5209.2315
# 2021-12-30           0.0      -13.3914      -11.6721   101.3387
# 2021-12-30           0.0       -4.7284      -11.6493    35.8616
# 2021-12-30           0.0      -20.8271      -11.6757   157.5529
# 2022-02-22           0.0      -23.9277       -4.3868   521.5223
# 2022-03-10           0.0       -4.2705       -1.5700   267.7295
# 2022-03-24           0.0      -16.9679       -6.2044   256.5121
# 2022-04-05           0.0      -16.9727       -6.2235   255.7473
# 2022-04-29           0.0        3.5925        1.3173   276.3125
# 2022-05-04           0.0       -3.8433       -1.4092   268.8767

# %%
df['Price Paid $'].plot(figsize=(15, 5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df['Value $'].plot(figsize=(15, 5), kind='bar')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df['Value $'].cumsum().plot(figsize=(15, 5), kind='bar')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df['Price Paid $'].plot.box(figsize=(15, 5))
# Out:
# <AxesSubplot: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 72 entries, 2021-08-02 to 2023-09-19
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Last Price $  72 non-null     float64
#  1   Change $      72 non-null     float64
#  2   Change %      72 non-null     float64
#  3   Quantity      72 non-null     float64
#  4   Price Paid $  72 non-null     float64
#  5   Day's Gain $  72 non-null     float64
#  6   Total Gain $  72 non-null     float64
#  7   Total Gain %  72 non-null     float64
#  8   Value $       72 non-null     float64
# dtypes: float64(9)
# memory usage: 5.6 KB

# %%
fig, ax = plt.subplots(1,2,figsize=(15,7))
sns.histplot(data=df, x = 'Price Paid $',ax = ax[0])
sns.boxplot(data=df, x = 'Price Paid $',ax = ax[1])
# Out:
# <AxesSubplot: xlabel='Price Paid $'>

# %%
sorted_data = df.sort_values(by='Price Paid $',ascending=False)
# sns.barplot(y = 'Date', x='Price Paid $',data=sorted_data.head(10)).set(title='Top 10 Highest Prices Paid')
sorted_data.head(10).plot(y='Price Paid $', kind='bar', figsize=(15, 5))
# Out:
# <AxesSubplot: xlabel='Date'>
