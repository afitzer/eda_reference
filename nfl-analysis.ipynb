# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in the passing data
df = pd.read_csv('data/team_stats09-15-23.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Team                       32 non-null     object
#  1   Passing Attempts           32 non-null     int64
#  2   Passing Completions        32 non-null     int64
#  3   Passing Completion %       32 non-null     float64
#  4   Passing Yards/Attempt      32 non-null     float64
#  5   Pass Yds                   32 non-null     int64
#  6   Passing TDs                32 non-null     int64
#  7   Passing Interceptions      32 non-null     int64
#  8   Passing Rate               32 non-null     float64
#  9   Passing 1st Downs          32 non-null     int64
#  10  Passing 1st Down %         32 non-null     float64
#  11  Passing 20+                32 non-null     int64
#  12  Passing 40+                32 non-null     int64
# ...

# %%
df
# Out:
#           Team  Passing Attempts  Passing Completions  Passing Completion %  \
# 0      Vikings                88                   64                  72.7
# 1       Eagles                56                   40                  71.4
# 2     Patriots                54                   35                  64.8
# 3     Steelers                46                   31                  67.4
# 4     Dolphins                45                   28                  62.2
# 5       Texans                44                   28                  63.6
# 6        Bills                41                   29                  70.7
# 7        Colts                39                   24                  61.5
# 8       Chiefs                39                   21                  53.8
# 9     Panthers                38                   20                  52.6
# 10        Rams                38                   24                  63.2
# ...

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
sns.histplot(df['Passing Completion %'],ax=ax[0])
sns.histplot(df['Passing Yards/Attempt'],ax=ax[1])
# Out:
# <AxesSubplot: xlabel='Passing Yards/Attempt', ylabel='Count'>
