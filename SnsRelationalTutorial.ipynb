# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="smoker", style="smoker")

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip", hue="size",
)

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip",
    size="size", sizes=(15, 200)
)

# %%
sns.displot(penguins, x="flipper_length_mm", kind="i")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\alexp\Documents\eda_reference\eda_reference\SnsRelationalTutorial.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alexp/Documents/eda_reference/eda_reference/SnsRelationalTutorial.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> sns.displot(penguins, x="flipper_length_mm", kind="i")
#
# File c:\Users\alexp\Documents\eda_reference\eda_reference\.venv\lib\site-packages\seaborn\distributions.py:2132, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2125 p = _DistributionFacetPlotter(
#    2126     data=data,
#    2127     variables=_DistributionFacetPlotter.get_semantics(locals())
#    2128 )
#    2130 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...

# %%
penguins = sns.load_dataset("penguins")

# %%
df = pd.read_csv('data/Activities (2).csv', parse_dates=['Date'], usecols=['Activity Type','Date', 'Distance', 'Time', 'Aerobic TE'])

# %%
# drop the time of day from the Date column
df['Date'] = pd.to_datetime(df['Date']).dt.date

# %%
df.head()
# Out:
#        Activity Type        Date  Distance        Time  Aerobic TE
# 0  Treadmill Running  2019-12-24      2.14    00:21:19         4.0
# 1            Running  2019-12-14      3.82    02:19:28         2.3
# 2            Running  2019-12-13      0.68  00:06:52.4         2.3
# 3  Treadmill Running  2019-12-10      1.08    00:12:50         2.0
# 4  Treadmill Running  2019-12-06      1.10    00:18:34         2.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Activity Type  385 non-null    object
#  1   Date           385 non-null    object
#  2   Distance       385 non-null    float64
#  3   Time           385 non-null    object
#  4   Aerobic TE     385 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 15.2+ KB

# %%
sns.relplot(data=df, x="Time", y="Distance", hue="Activity Type")
# Out:
# <AxesSubplot: xlabel='Time', ylabel='Distance'>

# %%
sns.displot(df, x="Distance", kind="kde")

# %%
g = sns.catplot(data=df, x="Activity Type", y="Distance", kind="bar")

g.fig.set_size_inches(7, 5)
